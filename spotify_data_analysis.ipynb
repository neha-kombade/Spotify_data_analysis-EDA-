# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("darkgrid")

# %% [markdown]
# # LOAD DATASET

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.021900    2    0.1650    -8.795     1       0.4310  150.062
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0           0        0.0102         0.833       204600   0.434
# 1           1        0.1990         0.743       326933   0.359
# 2           2        0.0344         0.838       185707   0.412
# 3           3        0.6040         0.494       199413   0.338
# 4           4        0.1800         0.678       392893   0.561
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0          0.021900    2    0.1650    -8.795     1       0.4310  150.062
# 1          0.006110    1    0.1370   -10.401     1       0.0794  160.083
# 2          0.000234    2    0.1590    -7.148     1       0.2890   75.044
# 3          0.510000    5    0.0922   -15.236     1       0.0261   86.468
# 4          0.512000    5    0.4390   -11.648     0       0.0694  174.004
#
#    time_signature  valence  target      song_title            artist
# 0             4.0    0.286       1        Mask Off            Future
# ...

# %% [markdown]
# # DATA CLEANNING

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# target              0
# song_title          0
# artist              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
# ...

# %%
df.shape
# Out:
# (2017, 17)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'target',
#        'song_title', 'artist'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 17

# %%
df.describe()
# Out:
#         Unnamed: 0  acousticness  danceability   duration_ms       energy  \
# count  2017.000000   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean   1008.000000      0.187590      0.618422  2.463062e+05     0.681577
# std     582.402066      0.259989      0.161029  8.198181e+04     0.210273
# min       0.000000      0.000003      0.122000  1.604200e+04     0.014800
# 25%     504.000000      0.009630      0.514000  2.000150e+05     0.563000
# 50%    1008.000000      0.063300      0.631000  2.292610e+05     0.715000
# 75%    1512.000000      0.265000      0.738000  2.703330e+05     0.846000
# max    2016.000000      0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# ...

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# ...

# %%
df.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of       Unnamed: 0  acousticness  danceability  duration_ms  energy  \
# 0              0       0.01020         0.833       204600   0.434
# 1              1       0.19900         0.743       326933   0.359
# 2              2       0.03440         0.838       185707   0.412
# 3              3       0.60400         0.494       199413   0.338
# 4              4       0.18000         0.678       392893   0.561
# ...          ...           ...           ...          ...     ...
# 2012        2012       0.00106         0.584       274404   0.932
# 2013        2013       0.08770         0.894       182182   0.892
# 2014        2014       0.00857         0.637       207200   0.935
# 2015        2015       0.00164         0.557       185600   0.992
# 2016        2016       0.00281         0.446       204520   0.915
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# ...

# %% [markdown]
# # DATA ANALYSIS

# %% [markdown]
# ### TOP 5 MOST POPULAR ARTITS

# %%
top_five_artists=df.groupby("artist").count().sort_values(by='song_title',ascending=False)['song_title'][:5]

# %%
top_five_artists
# Out:
# artist
# Drake              16
# Rick Ross          13
# Disclosure         12
# Backstreet Boys    10
# WALK THE MOON      10
# Name: song_title, dtype: int64

# %%
top_five_artists.plot.barh()
plt.show()

# %% [markdown]
# ### top 5 loudest tracks

# %%
top_five_loudest_tracks=df[['loudness','song_title']].sort_values(by="loudness")[:5]
top_five_loudest_tracks
# Out:
#       loudness                                         song_title
# 1594   -33.097            Lyric Pieces, Book I Op. 12: I. Arietta
# 1596   -31.367            8 Fantasiestücke, Op.12 : 1. Des Abends
# 1598   -31.082  Piano Quartet in E flat, Op.47: 3. Andante can...
# 1531   -30.447          I Was So Young, and You Were So Beautiful
# 1549   -29.460                                            Eleanor

# %%
top_five_loudest_tracks.plot.barh()
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='loudness',y='song_title',data=top_five_loudest_tracks)

plt.title("TOP 5 LOUDNESS TRAKES")
plt.show()

# %% [markdown]
# # ARTIST WITH THE MOST DANCEABILIY SONG

# %%
top_five_artits=df[['danceability','liveness','speechiness']].sort_values(by='danceability',ascending=False)[:5]
top_five_artits
# Out:
#       danceability  liveness  speechiness
# 1433         0.984    0.0260       0.0805
# 1901         0.967    0.0519       0.0789
# 604          0.962    0.1340       0.1080
# 32           0.959    0.3580       0.0713
# 1957         0.959    0.1500       0.0623

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='liveness',y='danceability',data=top_five_artits)

plt.title("TOP 5 ")
plt.show()

# %% [markdown]
# #  TOP 10 INSTRUMENTAL SONGS

# %%
top_10=df[['instrumentalness','song_title','artist']].sort_values(by='instrumentalness',ascending=False)[:9]
top_10
# Out:
#       instrumentalness                            song_title  \
# 1313             0.976                       Senseless Order
# 271              0.968  So Destroyed (channeling Rage Peace)
# 1575             0.964             A Hundred Dreams from Now
# 1619             0.958                                 Raven
# 725              0.957                     Strandbar (disko)
# 1546             0.956                        Almas vaggvisa
# 1322             0.955                            Pitchblack
# 1349             0.954                       Prismatic Abyss
# 1661             0.954                               Yebisah
#
#                         artist
# 1313        Signs of the Swarm
# 271                Prince Rama
# 1575                Ray Bryant
# 1619             John Dahlbäck
# 725                 Todd Terje
# 1546         Jan Lundgren Trio
# 1322  Walking Dead On Broadway
# 1349           Aversions Crown
# 1661               Mark Knight

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='instrumentalness',y='song_title',data=top_10)

plt.title("TOP 5 ")
plt.show()

# %%
plt.figure(figsize=(12,7))
plt.pie(x='instrumentalness',data=top_10,autopct='51.2fw',labels=top_10.song_title)
plt.show()

# %% [markdown]
# # MULTIPL FEATURE PLOTS

# %%
intrest_feature_cols=['tempo','loudness','acousticness','danceability','duration_ms','energy','instrumentalness','liveness','speechiness','valence']

# %%
for feature_col in intrest_feature_cols:
    pos_data = df[df['target'] == 1][feature_col]
    neg_data = df[df['target'] == 0][feature_col]
    plt.figure(figure=(12,7))
    sns.displot(pos_data,bins=30,label="Positive",color="green")
    sns.displot(neg_data,bins=30,label="Negative",color="red")
    plt.legend(loc="upper right")
    plt.title(f"Positive And Negative Histram plot for {feature_col}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[59], line 4
#       2 pos_data = df[df['target'] == 1][feature_col]
#       3 neg_data = df[df['target'] == 0][feature_col]
# ----> 4 plt.figure(figure=(12,7))
#       5 sns.displot(pos_data,bins=30,label="Positive",color="green")
#       6 sns.displot(neg_data,bins=30,label="Negative",color="red")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming intrest_feature_cols is a list of column names
for feature_col in intrest_feature_cols:
    pos_data = df[df['target'] == 1][feature_col]
    neg_data = df[df['target'] == 0][feature_col]

    # Create a new figure with subplots
    fig, axes = plt.subplots(figsize=(12, 7), nrows=1, ncols=2)

    # Plot positive data
    sns.histplot(pos_data, bins=30, label="Positive", color="green", ax=axes[0])
    axes[0].legend(loc="upper right")
    axes[0].set_title(f"Positive Histogram plot for {feature_col}")

    # Plot negative data
    sns.histplot(neg_data, bins=30, label="Negative", color="red", ax=axes[1])
    axes[1].legend(loc="upper right")
    axes[1].set_title(f"Negative Histogram plot for {feature_col}")

    # Adjust layout
    plt.tight_layout()

    # Show the plots
    plt.show()
